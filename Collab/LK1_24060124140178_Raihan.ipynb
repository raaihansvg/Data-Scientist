# %%
#Raihan Lazuardi
#24060124140178
#E


from google.colab import files
uploaded = files.upload()

import pandas as pd
df = pd.read_csv('Latihan.csv')

#untuk original data lat csv
print("Properti 1")
mean = df['Tipe3'].mean()
median = df['Tipe3'].median()

#untuk modified

Modified = df['Tipe3'] + 5

meanModified = Modified.mean()
medianModified = Modified.median()

print("Hasil Original Data")
print(f"mean: {mean:.2f}")
print(f"median: {median}")
print("                  ")

print("Hasil Modified Data")
print(f"meanModified: {meanModified:.2f}")
print(f"medianModified: {medianModified}")
print("                  ")


print("Properti 2")

print("Hasil Original Data 2")
print(f"mean: {mean:.2f}")
print(f"median: {median}")
print("                  ")

Modified2 = df['Tipe3'] * 2
meanModified2 = Modified2.mean()
medianModified2 = Modified2.median()

print("Hasil Modified Data 2")
print(f"meanModified: {meanModified2:.2f}")
print(f"medianModified: {medianModified2}")
print("                  ")


print("Properti 3")

print("Hasil Original Data 3")
print(f"mean: {mean:.2f}")
print(f"median: {median}")
print("                  ")


Outlayer = pd.Series(list(df['Tipe3']) +[1000])
meanModified3 = Outlayer.mean()
medianModified3 = Outlayer.median()

print("Hasil Modified Data 3")
print(f"meanModified: {meanModified3:.2f}")
print(f"medianModified: {medianModified3}")
# Out:
#      <input type="file" id="files-2336744d-5e8d-4362-b5bf-f20f898121d4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2336744d-5e8d-4362-b5bf-f20f898121d4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
